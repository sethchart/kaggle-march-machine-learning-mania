# %%
import pandas as pd
from itertools import permutations, combinations, product

# %% [markdown]
# Bring in our predictions

# %%
df_pred = pd.read_csv('/Users/tamraheberling/Documents/data_ml/MarchMadness/data/2022/predictions/phase2_submissions_xg.csv')
df_pred.head()
# Out:
#                ID      Pred
# 0  2022_1103_1104  0.159308
# 1  2022_1103_1112  0.064552
# 2  2022_1103_1116  0.182135
# 3  2022_1103_1120  0.061031
# 4  2022_1103_1124  0.092754

# %% [markdown]
# Excellent, now we have our submission file into a dataframe with ID and Predictions. From here we'll need to bring in the first round teams and see who we predict will win.

# %%
#read in the team data
df_teams = pd.read_csv('/Users/tamraheberling/Documents/data_ml/MarchMadness2023/data/raw/MTeams.csv')
df_teams.head()
# Out:
#    TeamID     TeamName  FirstD1Season  LastD1Season
# 0    1101  Abilene Chr           2014          2023
# 1    1102    Air Force           1985          2023
# 2    1103        Akron           1985          2023
# 3    1104      Alabama           1985          2023
# 4    1105  Alabama A&M           2000          2023

# %%
#read in the tournament slot data
df_slots = pd.read_csv('/Users/tamraheberling/Documents/data_ml/MarchMadness2023/data/raw/MNCAATourneySlots.csv')
df_slots.head()
# Out:
#    Season  Slot StrongSeed WeakSeed
# 0    1985  R1W1        W01      W16
# 1    1985  R1W2        W02      W15
# 2    1985  R1W3        W03      W14
# 3    1985  R1W4        W04      W13
# 4    1985  R1W5        W05      W12

# %%
df_slots_thisyear = df_slots[df_slots['Season']==2022]
df_slots_thisyear = df_slots_thisyear.reset_index(drop=True)
df_slots_thisyear.head(48)
# Out:
#     Season  Slot StrongSeed WeakSeed
# 0     2022  R1W1        W01      W16
# 1     2022  R1W2        W02      W15
# 2     2022  R1W3        W03      W14
# 3     2022  R1W4        W04      W13
# 4     2022  R1W5        W05      W12
# 5     2022  R1W6        W06      W11
# 6     2022  R1W7        W07      W10
# 7     2022  R1W8        W08      W09
# 8     2022  R1X1        X01      X16
# 9     2022  R1X2        X02      X15
# 10    2022  R1X3        X03      X14
# 11    2022  R1X4        X04      X13
# 12    2022  R1X5        X05      X12
# 13    2022  R1X6        X06      X11
# 14    2022  R1X7        X07      X10
# 15    2022  R1X8        X08      X09
# 16    2022  R1Y1        Y01      Y16
# 17    2022  R1Y2        Y02      Y15
# 18    2022  R1Y3        Y03      Y14
# 19    2022  R1Y4        Y04      Y13
# 20    2022  R1Y5        Y05      Y12
# 21    2022  R1Y6        Y06      Y11
# 22    2022  R1Y7        Y07      Y10
# 23    2022  R1Y8        Y08      Y09
# 24    2022  R1Z1        Z01      Z16
# 25    2022  R1Z2        Z02      Z15
# 26    2022  R1Z3        Z03      Z14
# 27    2022  R1Z4        Z04      Z13
# 28    2022  R1Z5        Z05      Z12
# 29    2022  R1Z6        Z06      Z11
# 30    2022  R1Z7        Z07      Z10
# 31    2022  R1Z8        Z08      Z09
# 32    2022  R2W1       R1W1     R1W8
# 33    2022  R2W2       R1W2     R1W7
# 34    2022  R2W3       R1W3     R1W6
# 35    2022  R2W4       R1W4     R1W5
# 36    2022  R2X1       R1X1     R1X8
# 37    2022  R2X2       R1X2     R1X7
# 38    2022  R2X3       R1X3     R1X6
# 39    2022  R2X4       R1X4     R1X5
# 40    2022  R2Y1       R1Y1     R1Y8
# 41    2022  R2Y2       R1Y2     R1Y7
# 42    2022  R2Y3       R1Y3     R1Y6
# 43    2022  R2Y4       R1Y4     R1Y5
# 44    2022  R2Z1       R1Z1     R1Z8
# 45    2022  R2Z2       R1Z2     R1Z7
# 46    2022  R2Z3       R1Z3     R1Z6
# 47    2022  R2Z4       R1Z4     R1Z5

# %%
#read in the tournament seed data data
df_seeds = pd.read_csv('/Users/tamraheberling/Documents/data_ml/MarchMadness2023/data/raw/MNCAATourneySeeds.csv')
df_seeds.head()
# Out:
#    Season Seed  TeamID
# 0    1985  W01    1207
# 1    1985  W02    1210
# 2    1985  W03    1228
# 3    1985  W04    1260
# 4    1985  W05    1374

# %%
df_seeds_thisyear = df_seeds[df_seeds['Season']==2022]
df_seeds_thisyear = df_seeds_thisyear.reset_index(drop=True)
df_seeds_thisyear.head(20)
# Out:
#     Season  Seed  TeamID
# 0     2022   W01    1124
# 1     2022   W02    1246
# 2     2022   W03    1345
# 3     2022   W04    1417
# 4     2022   W05    1388
# 5     2022   W06    1400
# 6     2022   W07    1293
# 7     2022   W08    1314
# 8     2022   W09    1266
# 9     2022   W10    1362
# 10    2022   W11    1439
# 11    2022  W12a    1231
# 12    2022  W12b    1461
# 13    2022   W13    1103
# 14    2022   W14    1463
# 15    2022   W15    1389
# 16    2022   W16    1313
# 17    2022   X01    1211
# 18    2022   X02    1181
# 19    2022   X03    1403

# %% [markdown]
# Eliminate the letters for the playin games

# %%
df_seeds_thisyear.Seed.replace(['W12a','Y16a','X11a','Z16a'],['W12','Y16','X11','Z16'],inplace=True)
vals_to_drop=['W12b','X11b','Y16b','Z16b']
df_seeds_thisyear = df_seeds_thisyear[df_seeds_thisyear.Seed.isin(vals_to_drop) == False]

# %%
print(df_seeds_thisyear[32:64])
# Out:
#     Season Seed  TeamID
# 34    2022  Y01    1242
# 35    2022  Y02    1120
# 36    2022  Y03    1458
# 37    2022  Y04    1344
# 38    2022  Y05    1234
# 39    2022  Y06    1261
# 40    2022  Y07    1425
# 41    2022  Y08    1361
# 42    2022  Y09    1166
# 43    2022  Y10    1274
# 44    2022  Y11    1235
# 45    2022  Y12    1350
# 46    2022  Y13    1355
# 47    2022  Y14    1159
# 48    2022  Y15    1240
# 49    2022  Y16    1394
# 51    2022  Z01    1112
# 52    2022  Z02    1437
# 53    2022  Z03    1397
# 54    2022  Z04    1228
# 55    2022  Z05    1222
# 56    2022  Z06    1161
# 57    2022  Z07    1326
# 58    2022  Z08    1371
# 59    2022  Z09    1395
# 60    2022  Z10    1260
# 61    2022  Z11    1276
# 62    2022  Z12    1412
# 63    2022  Z13    1151
# 64    2022  Z14    1255
# 65    2022  Z15    1174
# 66    2022  Z16    1136

# %% [markdown]
# I think with these three dataframes, we can write a function that will take the slot information to find out which slots play eachother in each round. Then we use the seed data frame to look up which TeamID is associated with the slots. Then we look at our predictions to find out who we predicted to win. From there we should be able to label the winning teams with their seed for the next round and continue on.

# %%
'''Given two integers 0,8 for W round 1, return a list of Strong Seeds and a list of Weak Seeds'''
def match_upID(int1:int,int2:int):
    StrongSeed = df_slots_thisyear.StrongSeed[int1:int2]
    WeakSeed = df_slots_thisyear.WeakSeed[int1:int2]
    TeamID_Strong = [int(df_seeds_thisyear.TeamID[df_seeds_thisyear.Seed==seed]) for seed in StrongSeed]
    TeamID_Weak = [int(df_seeds_thisyear.TeamID[df_seeds_thisyear.Seed==seed]) for seed in WeakSeed]
    return TeamID_Strong,TeamID_Weak

# %%
'''Given the TeamID of the strong and weak seed in the match up, which TeamName 
was predicted to be the winner''' 
def winners(strong:int,weak:int):
    if strong > weak:
        id_pred = '2022_'+str(weak)+'_'+str(strong)
        pred = float(df_pred.Pred[df_pred.ID==id_pred])
        print(pred)
        weak_win_prob = pred
        strong_win_prob = 1-pred
        if pred < 0.5:
            win_teamID = strong
            win_team = df_teams.loc[df_teams.TeamID == win_teamID,'TeamName'].iloc[0]
            print('winner '+win_team)
        elif pred > 0.5:
            win_teamID = weak
            win_team = df_teams.loc[df_teams.TeamID == win_teamID,'TeamName'].iloc[0]
            print('winner '+win_team)
    elif strong < weak:
        id_pred = '2022_'+str(strong)+'_'+str(weak)
        pred = float(df_pred.Pred[df_pred.ID==id_pred])
        print(pred)
        strong_win_prob = pred
        weak_win_prob = 1-pred
        if pred < 0.5:
            win_teamID = weak
            win_team = df_teams.loc[df_teams.TeamID == win_teamID,'TeamName'].iloc[0]
            print('winner '+win_team)
        elif pred > 0.5:
            win_teamID = strong
            win_team = df_teams.loc[df_teams.TeamID == win_teamID,'TeamName'].iloc[0]
            print('winner '+win_team)
    return win_team, strong_win_prob, weak_win_prob

# %%
'''Take the list of Strong TeamIDs and Weak TeamIDs, and use the winners function 
to make a dictionary of the winning team and the rank for the next round.'''
def round_winners(strong_teams:list, weak_teams:list, end_rank:str):
    rank = [end_rank+'{}'.format(i+1) for i in range(8)]
    winning_teams = []
    strong_win_probs = []
    weak_win_probs = []
    for i in range(len(strong_teams)):
        strong_id = strong_teams[i]
        weak_id = weak_teams[i]
        winner,strong_win_prob,weak_win_prob = winners(strong_id, weak_id)
        winning_teams.append(str(winner))
        strong_win_probs.append(strong_win_prob)
        weak_win_probs.append(weak_win_prob)
    round_wins = dict(zip(winning_teams,rank))
    return round_wins, strong_win_probs, weak_win_probs

# %%
'''Make a disctionary of the rank of each team and the probability that they win the round'''
def prob_win(strong_pred, weak_pred):
    round1_rank = [i+1 for i in range(16)]
    weak_pred = list(reversed(weak_pred))
    pred_list = strong_pred+weak_pred
    rank_prob = dict(zip(round1_rank,pred_list))
    return rank_prob

# %% [markdown]
# # Region: W
# # Round: 1

# %%
TeamID_Strong, TeamID_Weak = match_upID(0,8)
TeamID_Strong, TeamID_Weak
# Out:
# ([1124, 1246, 1345, 1417, 1388, 1400, 1293, 1314],
#  [1313, 1389, 1463, 1103, 1231, 1439, 1362, 1266])

# %%
round1_w,strong_pred,weak_pred = round_winners(TeamID_Strong,TeamID_Weak,'R1W')
round1_w
# Out:
# 0.92234504
# winner Baylor
# 0.8724796
# winner Kentucky
# 0.89320433
# winner Purdue
# 0.113508396
# winner UCLA
# 0.41570774
# winner St Mary's CA
# 0.74389285
# winner Texas
# 0.51378846
# winner Murray St
# 0.54290676
# winner Marquette
# {'Baylor': 'R1W1',
#  'Kentucky': 'R1W2',
#  'Purdue': 'R1W3',
#  'UCLA': 'R1W4',
#  "St Mary's CA": 'R1W5',
#  'Texas': 'R1W6',
#  'Murray St': 'R1W7',
#  'Marquette': 'R1W8'}

# %%
round1_prob_by_rank = prob_win(strong_pred, weak_pred)
round1_prob_by_rank
# Out:
# {1: 0.92234504,
#  2: 0.8724796,
#  3: 0.89320433,
#  4: 0.886491604,
#  5: 0.58429226,
#  6: 0.74389285,
#  7: 0.51378846,
#  8: 0.45709323999999996,
#  9: 0.54290676,
#  10: 0.48621154,
#  11: 0.25610714999999995,
#  12: 0.41570774,
#  13: 0.113508396,
#  14: 0.10679567000000001,
#  15: 0.12752039999999998,
#  16: 0.07765496000000005}

# %%
'''function to calculate all the possible round 1 results and their probabilities'''
def round1_results(round1_prob_by_rank):
    #calculate all possible combinations of ranks from round 1 as a list of tuples
    round1_matchups = [[1,16],[2,15],[3,14],[4,13],[5,12],[6,11],[7,10],[8,9]]
    possible_combos = list(product(*round1_matchups))
    #use dict to pull the probability that each team in the tuple wins and multiply together to calculate the probability of that tuple
    probability_of_combos = []
    for i in possible_combos:
        prob_combo = 1
        for j in i:
            prob_j = round_1_prob_by_rank[j]
            prob_combo = prob_combo*prob_j
        probability_of_combos.append(prob_combo)
    round1_results_dict = dict(zip(possible_combos,probability_of_combos))
    return(round1_results_dict)

# %%
round1_results_pred = round1_results(round1_prob_by_rank)
round1_results_pred
# Out:
# {(1, 2, 3, 4, 5, 6, 7, 8): 0.06504348555154586,
#  (1, 2, 3, 4, 5, 6, 7, 9): 0.07725458376915963,
#  (1, 2, 3, 4, 5, 6, 10, 8): 0.06155236199151859,
#  (1, 2, 3, 4, 5, 6, 10, 9): 0.07310804556891393,
#  (1, 2, 3, 4, 5, 11, 7, 8): 0.022393146688629403,
#  (1, 2, 3, 4, 5, 11, 7, 9): 0.0265971789802197,
#  (1, 2, 3, 4, 5, 11, 10, 8): 0.021191223985303993,
#  (1, 2, 3, 4, 5, 11, 10, 9): 0.02516961037160751,
#  (1, 2, 3, 4, 12, 6, 7, 8): 0.04627663625110452,
#  (1, 2, 3, 4, 12, 6, 7, 9): 0.05496449400736206,
#  (1, 2, 3, 4, 12, 6, 10, 8): 0.04379279865038105,
#  (1, 2, 3, 4, 12, 6, 10, 9): 0.05201434706540563,
#  (1, 2, 3, 4, 12, 11, 7, 8): 0.015932102885324224,
#  (1, 2, 3, 4, 12, 11, 7, 9): 0.018923155278905517,
#  (1, 2, 3, 4, 12, 11, 10, 8): 0.015076968212388294,
#  (1, 2, 3, 4, 12, 11, 10, 9): 0.017907479801737434,
