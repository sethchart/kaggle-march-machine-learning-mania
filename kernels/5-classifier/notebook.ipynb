# %% [markdown]
# Let's see how we do with xgboost

# %%
import pandas as pd

# Matplotlib for visualization
from matplotlib import pyplot as plt
# display plots in the notebook
# %matplotlib inline 

from xgboost import XGBClassifier
# Import RandomForestClassifier and GradientBoostingClassifer
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# Function for splitting training and test set
from sklearn.model_selection import train_test_split
# Function for creating model pipelines
from sklearn.pipeline import make_pipeline
# For standardization
from sklearn.preprocessing import StandardScaler
# Helper for cross-validation
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# %% [markdown]
# Let's load in the dataset from the processed data folder.

# %%
df = pd.read_csv('../input/3-merge-datasets-step-1/model_dataset.csv')
df.head()
# Out:
#    Unnamed: 0  Season  LowID  HighID  Win   LowScore    LowFGP   LowFGP3  \
# 0           0    2003   1411    1421    0  72.800000  0.448892  0.321414
# 1           1    2003   1112    1436    1  85.214286  0.463563  0.351060
# 2           2    2003   1113    1272    1  75.965517  0.481680  0.328376
# 3           3    2003   1141    1166    1  79.344828  0.506349  0.377481
# 4           4    2003   1143    1301    1  74.482759  0.468741  0.375934
#
#      LowFTP      LowOR  ...   HighFTP     HighOR     HighDR    HighAst  \
# 0  0.613745  13.166667  ...  0.766142  12.275862  23.172414  13.034483
# 1  0.701154  15.178571  ...  0.649708  12.965517  25.724138  14.206897
# 2  0.675667  13.689655  ...  0.628299  14.068966  25.965517  16.620690
# 3  0.762741  10.586207  ...  0.689707  10.878788  23.181818  16.818182
# 4  0.688632  11.241379  ...  0.778148   9.733333  22.033333  14.666667
#
#       HighTO   HighStl   HighBlk     HighPF    HighRank  HighSeed
# 0  16.206897  7.068966  3.000000  19.103448  240.343750      16.0
# 1  14.068966  6.862069  2.965517  15.896552  153.125000      16.0
# 2  13.793103  7.379310  5.068966  18.758621   21.705882       7.0
# 3  13.363636  8.393939  4.454545  17.272727   20.735294       6.0
# 4  14.200000  7.766667  3.066667  18.666667   50.312500       9.0
#
# [5 rows x 31 columns]

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'Season', 'LowID', 'HighID', 'Win', 'LowScore',
#        'LowFGP', 'LowFGP3', 'LowFTP', 'LowOR', 'LowDR', 'LowAst', 'LowTO',
#        'LowStl', 'LowBlk', 'LowPF', 'LowRank', 'LowSeed', 'HighScore',
#        'HighFGP', 'HighFGP3', 'HighFTP', 'HighOR', 'HighDR', 'HighAst',
#        'HighTO', 'HighStl', 'HighBlk', 'HighPF', 'HighRank', 'HighSeed'],
#       dtype=object)

# %%
df = df.drop(columns = ['Unnamed: 0'])
df.head()
# Out:
#    Season  LowID  HighID  Win   LowScore    LowFGP   LowFGP3    LowFTP  \
# 0    2003   1411    1421    0  72.800000  0.448892  0.321414  0.613745
# 1    2003   1112    1436    1  85.214286  0.463563  0.351060  0.701154
# 2    2003   1113    1272    1  75.965517  0.481680  0.328376  0.675667
# 3    2003   1141    1166    1  79.344828  0.506349  0.377481  0.762741
# 4    2003   1143    1301    1  74.482759  0.468741  0.375934  0.688632
#
#        LowOR      LowDR  ...   HighFTP     HighOR     HighDR    HighAst  \
# 0  13.166667  24.800000  ...  0.766142  12.275862  23.172414  13.034483
# 1  15.178571  27.642857  ...  0.649708  12.965517  25.724138  14.206897
# 2  13.689655  23.310345  ...  0.628299  14.068966  25.965517  16.620690
# 3  10.586207  23.275862  ...  0.689707  10.878788  23.181818  16.818182
# 4  11.241379  24.379310  ...  0.778148   9.733333  22.033333  14.666667
#
#       HighTO   HighStl   HighBlk     HighPF    HighRank  HighSeed
# 0  16.206897  7.068966  3.000000  19.103448  240.343750      16.0
# 1  14.068966  6.862069  2.965517  15.896552  153.125000      16.0
# 2  13.793103  7.379310  5.068966  18.758621   21.705882       7.0
# 3  13.363636  8.393939  4.454545  17.272727   20.735294       6.0
# 4  14.200000  7.766667  3.066667  18.666667   50.312500       9.0
#
# [5 rows x 30 columns]

# %% [markdown]
# We need to split the data so it's the target and input features.

# %%
# Create separate object for target variable
y = df.Win

# Create separate object for input features
X = df.drop('Win', axis=1)

# %% [markdown]
# Split into training and test data with 20% of the observations going to the test set. We also give it a random state so we can reproduce the results.

# %%
# Split X and y into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=1234)

# Print number of observations in X_train, X_test, y_train, and y_test
print(len(X_train), len(X_test), len(y_train), len(y_test))
# Out:
# 944 237 944 237

# %% [markdown]
# Ok time for pipelines.

# %%
# Pipeline dictionary
pipelines = {
    'xg': make_pipeline(StandardScaler(),XGBClassifier(random_state=123)),
    'gb': make_pipeline(StandardScaler(),GradientBoostingClassifier(random_state=123))
            }

# %%
# Boosted Tree hyperparameters
gb_hyperparameters = {'gradientboostingclassifier__n_estimators': [200],
                     'gradientboostingclassifier__learning_rate': [0.05],
                     'gradientboostingclassifier__max_depth': [1]}

# %%
# Boosted Tree hyperparameters
xg_hyperparameters = {
'xgbclassifier__max_depth': range (2, 10, 1),
    'xgbclassifier__n_estimators': range(60, 220, 40),
    'xgbclassifier__learning_rate': [0.1, 0.01, 0.05]
}

# %%
# Create hyperparameters dictionary
hyperparameters = {
    'xg': xg_hyperparameters,
    'gb': gb_hyperparameters
}

# %%
# Create empty dictionary called fitted_models
fitted_models = {}

# Loop through model pipelines, tuning each one and saving it to fitted_models
for name, pipeline in pipelines.items():
    # Create cross-validation object from pipeline and hyperparameters
    model = GridSearchCV(pipeline, hyperparameters[name], cv=10, n_jobs=-1, scoring='neg_log_loss')
    
    # Fit model on X_train, y_train
    model.fit(X_train,y_train)
    
    # Store model in fitted_models[name] 
    fitted_models[name] = model
    
    # Print '{name} has been fitted'
    print(name, 'has been fitted')

# %%
fitted_models['xg']

# %%
model_xg = fitted_models['xg']

# %%
y_pred = model_xg.predict(X_test)
predictions = [round(value) for value in y_pred]

# %%
accuracy = accuracy_score(y_test, predictions)
print(accuracy)

# %% [markdown]
# If I play around by hand I can get a little bit better accuracy.

# %%
model = XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1,
       gamma=0, learning_rate=0.5, max_delta_step=2, max_depth=10,
       min_child_weight=1, missing=None, n_estimators=300, nthread=-1,reg_alpha=0, reg_lambda=1,
       scale_pos_weight=1, seed=0, silent=True, subsample=1)

# %%
model.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [01:40:34] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [01:40:34] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.5, max_delta_step=2,
#               max_depth=10, min_child_weight=1, missing=None,
#               monotone_constraints='()', n_estimators=300, n_jobs=4, nthread=-1,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=0,
#               silent=True, subsample=1, tree_method='exact',
#               validate_parameters=1, ...)

# %%
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# /tmp/ipykernel_34/1740174754.py in <module>
# ----> 1 y_pred = model.predict(X_test)
#       2 predictions = [round(value) for value in y_pred]
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#    1288             validate_features=validate_features,
#    1289             base_margin=base_margin,
# -> 1290             iteration_range=iteration_range,
#    1291         )
#    1292         if output_margin:
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#     885                     missing=self.missing,
#     886                     base_margin=base_margin,
# --> 887                     validate_features=validate_features,
#     888                 )
#     889                 if _is_cupy_array(predts):
#
# /opt/conda/lib/python3.7/site-packages/xgboost/core.py in inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2046                     ctypes.byref(shape),
#    2047                     ctypes.byref(dims),
# -> 2048                     ctypes.byref(preds),
#    2049                 )
#    2050             )
#
# /opt/conda/lib/python3.7/site-packages/xgboost/core.py in _check_call(ret)
#     216     """
#     217     if ret != 0:
# --> 218         raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#     219
#     220
#
# XGBoostError: [01:40:41] ../src/c_api/c_api_utils.h:161: Invalid missing value: null
# Stack trace:
#   [bt] (0) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(+0x9733d) [0x7f05ce53433d]
#   [bt] (1) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(+0xaf4ec) [0x7f05ce54c4ec]
#   [bt] (2) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(+0xb560f) [0x7f05ce55260f]
#   [bt] (3) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(XGBoosterPredictFromDense+0x28d) [0x7f05ce53852d]
#   [bt] (4) /opt/conda/lib/python3.7/lib-dynload/../../libffi.so.8(+0x6a4a) [0x7f0657fe7a4a]
#   [bt] (5) /opt/conda/lib/python3.7/lib-dynload/../../libffi.so.8(+0x5fea) [0x7f0657fe6fea]
#   [bt] (6) /opt/conda/lib/python3.7/lib-dynload/_ctypes.cpython-37m-x86_64-linux-gnu.so(_ctypes_callproc+0x2f4) [0x7f0657ffd784]
#   [bt] (7) /opt/conda/lib/python3.7/lib-dynload/_ctypes.cpython-37m-x86_64-linux-gnu.so(+0x10ff8) [0x7f0657ffdff8]
#   [bt] (8) /opt/conda/bin/python(_PyObject_FastCallKeywords+0x47b) [0x55aa80aee72b]

# %%
accuracy = accuracy_score(y_test, predictions)
print(accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_34/122563912.py in <module>
# ----> 1 accuracy = accuracy_score(y_test, predictions)
#       2 print(accuracy)
#
# NameError: name 'predictions' is not defined

# %% [markdown]
# That seems to be pretty decent. Most of the values that I was playing with gave me somewhere between 66 and 70. Let's check it against the winning gradient boosting model from 3.0-theberling-classifier.ipynb

# %%
model2 = GradientBoostingClassifier(n_estimators=200,learning_rate=0.05,max_depth=1)

# %%
model2.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.05, max_depth=1, n_estimators=200)

# %%
y_pred2 = model2.predict(X_test)
predictions2 = [round(value) for value in y_pred2]

# %%
accuracy2 = accuracy_score(y_test, predictions2)
print(accuracy2)
# Out:
# 0.7130801687763713

# %% [markdown]
# Let's run it on our submission data set and see what happens.

# %%
data = pd.read_csv('../input/4-merge-datasets-step-2/model_dataset2.csv')
data.head()
# Out:
#    Season  LowID  HighID   LowScore   LowFGP  LowFGP3    LowFTP      LowOR  \
# 0    2016   1112    1114  81.212121  0.48596  0.37945  0.725924  11.636364
# 1    2016   1112    1122  81.212121  0.48596  0.37945  0.725924  11.636364
# 2    2016   1112    1124  81.212121  0.48596  0.37945  0.725924  11.636364
# 3    2016   1112    1138  81.212121  0.48596  0.37945  0.725924  11.636364
# 4    2016   1112    1139  81.212121  0.48596  0.37945  0.725924  11.636364
#
#        LowDR     LowAst  ...   HighFTP     HighOR     HighDR    HighAst  \
# 0  28.606061  14.515152  ...  0.727142   8.709677  24.193548  12.903226
# 1  28.606061  14.515152  ...  0.662456  11.090909  24.787879  12.878788
# 2  28.606061  14.515152  ...  0.721206  13.562500  23.218750  17.093750
# 3  28.606061  14.515152  ...  0.714150  12.090909  26.727273  12.545455
# 4  28.606061  14.515152  ...  0.726300  11.419355  25.000000  14.354839
#
#       HighTO   HighStl   HighBlk     HighPF    HighRank  HighSeed
# 0  10.225806  6.290323  3.064516  18.258065   55.457627      12.0
# 1  14.545455  6.909091  2.757576  17.636364  208.293103      16.0
# 2  12.812500  7.718750  3.968750  19.406250   24.229508       5.0
# 3  13.818182  6.727273  3.484848  21.272727  122.465517      14.0
# 4  10.225806  6.774194  3.354839  19.903226   34.241379       9.0
#
# [5 rows x 29 columns]

# %%
predictions = model.predict(data)
predictions
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# /tmp/ipykernel_34/3024959604.py in <module>
# ----> 1 predictions = model.predict(data)
#       2 predictions
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#    1288             validate_features=validate_features,
#    1289             base_margin=base_margin,
# -> 1290             iteration_range=iteration_range,
#    1291         )
#    1292         if output_margin:
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#     885                     missing=self.missing,
#     886                     base_margin=base_margin,
# --> 887                     validate_features=validate_features,
#     888                 )
#     889                 if _is_cupy_array(predts):
#
# /opt/conda/lib/python3.7/site-packages/xgboost/core.py in inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2046                     ctypes.byref(shape),
#    2047                     ctypes.byref(dims),
# -> 2048                     ctypes.byref(preds),
#    2049                 )
#    2050             )
#
# /opt/conda/lib/python3.7/site-packages/xgboost/core.py in _check_call(ret)
#     216     """
#     217     if ret != 0:
# --> 218         raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#     219
#     220
#
# XGBoostError: [01:41:59] ../src/c_api/c_api_utils.h:161: Invalid missing value: null
# Stack trace:
#   [bt] (0) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(+0x9733d) [0x7f05ce53433d]
#   [bt] (1) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(+0xaf4ec) [0x7f05ce54c4ec]
#   [bt] (2) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(+0xb560f) [0x7f05ce55260f]
#   [bt] (3) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(XGBoosterPredictFromDense+0x28d) [0x7f05ce53852d]
#   [bt] (4) /opt/conda/lib/python3.7/lib-dynload/../../libffi.so.8(+0x6a4a) [0x7f0657fe7a4a]
#   [bt] (5) /opt/conda/lib/python3.7/lib-dynload/../../libffi.so.8(+0x5fea) [0x7f0657fe6fea]
#   [bt] (6) /opt/conda/lib/python3.7/lib-dynload/_ctypes.cpython-37m-x86_64-linux-gnu.so(_ctypes_callproc+0x2f4) [0x7f0657ffd784]
#   [bt] (7) /opt/conda/lib/python3.7/lib-dynload/_ctypes.cpython-37m-x86_64-linux-gnu.so(+0x10ff8) [0x7f0657ffdff8]
#   [bt] (8) /opt/conda/bin/python(_PyObject_FastCallKeywords+0x47b) [0x55aa80aee72b]

# %%
probs = model.predict_proba(data)
probs
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# /tmp/ipykernel_34/587205697.py in <module>
# ----> 1 probs = model.predict_proba(data)
#       2 probs
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py in predict_proba(self, X, ntree_limit, validate_features, base_margin, iteration_range)
#    1352             validate_features=validate_features,
#    1353             base_margin=base_margin,
# -> 1354             iteration_range=iteration_range
#    1355         )
#    1356         # If model is loaded from a raw booster there's no `n_classes_`
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#     885                     missing=self.missing,
#     886                     base_margin=base_margin,
# --> 887                     validate_features=validate_features,
#     888                 )
#     889                 if _is_cupy_array(predts):
#
# /opt/conda/lib/python3.7/site-packages/xgboost/core.py in inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2046                     ctypes.byref(shape),
#    2047                     ctypes.byref(dims),
# -> 2048                     ctypes.byref(preds),
#    2049                 )
#    2050             )
#
# /opt/conda/lib/python3.7/site-packages/xgboost/core.py in _check_call(ret)
#     216     """
#     217     if ret != 0:
# --> 218         raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#     219
#     220
#
# XGBoostError: [01:42:12] ../src/c_api/c_api_utils.h:161: Invalid missing value: null
# Stack trace:
#   [bt] (0) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(+0x9733d) [0x7f05ce53433d]
#   [bt] (1) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(+0xaf4ec) [0x7f05ce54c4ec]
#   [bt] (2) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(+0xb560f) [0x7f05ce55260f]
#   [bt] (3) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(XGBoosterPredictFromDense+0x28d) [0x7f05ce53852d]
#   [bt] (4) /opt/conda/lib/python3.7/lib-dynload/../../libffi.so.8(+0x6a4a) [0x7f0657fe7a4a]
#   [bt] (5) /opt/conda/lib/python3.7/lib-dynload/../../libffi.so.8(+0x5fea) [0x7f0657fe6fea]
#   [bt] (6) /opt/conda/lib/python3.7/lib-dynload/_ctypes.cpython-37m-x86_64-linux-gnu.so(_ctypes_callproc+0x2f4) [0x7f0657ffd784]
#   [bt] (7) /opt/conda/lib/python3.7/lib-dynload/_ctypes.cpython-37m-x86_64-linux-gnu.so(+0x10ff8) [0x7f0657ffdff8]
#   [bt] (8) /opt/conda/bin/python(_PyObject_FastCallKeywords+0x47b) [0x55aa80aee72b]

# %%
prob_of_1 = probs[:,1]
prob_of_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_34/2199530115.py in <module>
# ----> 1 prob_of_1 = probs[:,1]
#       2 prob_of_1
#
# NameError: name 'probs' is not defined

# %%
def make_id(row):
    season = row[0]
    low_id = row[1]
    high_id = row[2]
    ID = str(int(season))+'_'+str(int(low_id))+'_'+str(int(high_id))
    return ID

# %%
ID = data.apply(make_id,axis=1)

# %%
df_submission = pd.DataFrame()

# %%
df_submission['ID'] = ID
df_submission['Pred'] = prob_of_1
df_submission.head()

# %%
df_submission.to_csv('kaggle/working/phase1_submissions1.csv',index=False)

# %% [markdown]
# Out of curiousity let's look at the feature importance.

# %%
model.feature_importances_

# %%
feature_names = X.columns

# %%
plt.barh(feature_names, model.feature_importances_)

# %% [markdown]
# What about gradient boost?

# %%
model2.feature_importances_

# %%
plt.barh(feature_names, model2.feature_importances_)
